# %%
import pandas as pd

# %%
ko_cn_chat = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-cn_chat.xlsx")

# %%
ko_cn_chat = ko_cn_chat[['원문', '최종번역문']]
ko_cn_chat.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

# %%
ko_jp_chat = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-jp_chat.xlsx")

# %%
ko_jp_chat = ko_jp_chat[['원문', '최종번역문']]
ko_jp_chat.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)
# Out:
# /tmp/ipykernel_1093219/4152083976.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ko_jp_chat.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

# %%
ko_cn_chat['source_language'] = 'ko'
ko_cn_chat['target_language'] = 'cn'
ko_jp_chat['source_language'] = 'ko'
ko_jp_chat['target_language'] = 'jp'
# Out:
# /tmp/ipykernel_1093219/2110377230.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ko_jp_chat['source_language'] = 'ko'
# /tmp/ipykernel_1093219/2110377230.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ko_jp_chat['target_language'] = 'jp'

# %%
all_chat_data = pd.concat([ko_cn_chat, ko_jp_chat], axis=0)

# %%
# all_chat_data.to_csv("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/all_chat_data.csv")

# %%
ko_cn_daily = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-cn_daily.xlsx")

# %%
ko_cn_daily = ko_cn_daily[['원문', '최종번역문']]
ko_cn_daily.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)
# Out:
# /tmp/ipykernel_1093219/3698955809.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ko_cn_daily.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

# %%
ko_jp_daily = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-jp_daily.xlsx")

# %%
ko_jp_daily = ko_jp_daily[['원문', '최종번역문']]
ko_jp_daily.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

# %%
ko_cn_daily['source_language'] = 'ko'
ko_cn_daily['target_language'] = 'cn'
ko_jp_daily['source_language'] = 'ko'
ko_jp_daily['target_language'] = 'jp'
# Out:
# /tmp/ipykernel_1093219/4152369192.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ko_cn_daily['source_language'] = 'ko'
# /tmp/ipykernel_1093219/4152369192.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ko_cn_daily['target_language'] = 'cn'

# %%
all_daily_data = pd.concat([ko_cn_daily, ko_jp_daily], axis=0)

# %%
# all_daily_data.to_csv("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/all_daily_data.csv")

# %%
all_data = pd.concat([all_daily_data, all_chat_data], axis=0)

# %%
all_data
# Out:
#                             kor_original                         translate  \
# 0                         매장 문도 거의 닫혀있네.                        卖场门也几乎都关了。
# 1                       응, 코로나가 언제 종식될까?                  嗯，新冠病毒什么时候才能结束呢？
# 2          맞아, 빨리 코로나가 종식되어 마음껏 여행하고 싶다.               没错，想快点结束新冠疫情，尽情地旅行。
# 3       그런데 요즘 전세계적으로 델타 변이 바이러스가 너무 심해.              但是最近全世界的德尔塔变异毒株太严重了。
# 4                맞아, 델타 변이 바이러스가 너무 심하지.                   没错，德尔塔变异毒株是很严重。
# ...                                  ...                               ...
# 119995            신풍을 보고 나왔습니까? 무슨 일이시죠.               新風を観てきました、どうしたんですか？
# 119996                계단에 몸을 웅크리고 앉아 있어?                   階段にしゃがんで座っているの？
# 119997                  영화관 위치 좀 물어보려고요?            映画館の位置を教えていただけますでしょうか？
# 119998               제 좌석에 팝콘이 엎질러져 있어요?            私の座席にポップコーンがこぼれてありますか？
# 119999  그리고 코인 현질을 했는데 아직도 추가 코인이 안 왔어요?  そしてコインを課金したのですが、まだ追加コインが来ていませんか？
#
#        source_language target_language
# ...

# %%
all_data.drop_duplicates(subset='kor_original')
# Out:
#                             kor_original                         translate  \
# 0                         매장 문도 거의 닫혀있네.                        卖场门也几乎都关了。
# 1                       응, 코로나가 언제 종식될까?                  嗯，新冠病毒什么时候才能结束呢？
# 2          맞아, 빨리 코로나가 종식되어 마음껏 여행하고 싶다.               没错，想快点结束新冠疫情，尽情地旅行。
# 3       그런데 요즘 전세계적으로 델타 변이 바이러스가 너무 심해.              但是最近全世界的德尔塔变异毒株太严重了。
# 4                맞아, 델타 변이 바이러스가 너무 심하지.                   没错，德尔塔变异毒株是很严重。
# ...                                  ...                               ...
# 119833                 그렇게 자리 교환해드리겠습니까?                   そのように席を交換致しますか？
# 119834                      결제하신 카드 주세요?               お支払いいただいたカードをくださいか？
# 119835                 여기 영수증이랑 결제한 카드요?                   領収書と決済したカードですか？
# 119836                   결제한 카드 주시면 됩니다?                 決済したカードだけお願いしますか？
# 119999  그리고 코인 현질을 했는데 아직도 추가 코인이 안 왔어요?  そしてコインを課金したのですが、まだ追加コインが来ていませんか？
#
#        source_language target_language
# ...

# %%
# all_data = all_data.drop_duplicates(subset='kor_original').reset_index(drop=True)
# all_data.to_csv("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/all_data.csv")

# %%
ko_jp_chat_test = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-jp_chat_test.xlsx")
ko_jp_daily_test = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-jp_daily_test.xlsx")
ko_cn_chat_test = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-cn_chat_test.xlsx")
ko_cn_daily_test = pd.read_excel("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/ko-cn_daily_test.xlsx")

# %%
ko_jp_chat_test = ko_jp_chat_test[['원문', '최종번역문']]
ko_jp_chat_test.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

ko_jp_daily_test = ko_jp_daily_test[['원문', '최종번역문']]
ko_jp_daily_test.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

ko_cn_chat_test = ko_cn_chat_test[['원문', '최종번역문']]
ko_cn_chat_test.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

ko_cn_daily_test = ko_cn_daily_test[['원문', '최종번역문']]
ko_cn_daily_test.rename(columns={'원문' : 'kor_original', '최종번역문':'translate'}, inplace=True)

# %%
ko_cn_daily_test['source_language'] = 'ko'
ko_cn_daily_test['target_language'] = 'cn'
ko_jp_daily_test['source_language'] = 'ko'
ko_jp_daily_test['target_language'] = 'jp'

ko_cn_chat_test['source_language'] = 'ko'
ko_cn_chat_test['target_language'] = 'cn'
ko_jp_chat_test['source_language'] = 'ko'
ko_jp_chat_test['target_language'] = 'jp'

# %%
datalist = [ko_jp_chat_test, ko_jp_daily_test, ko_cn_chat_test, ko_cn_daily_test]
data = pd.concat(datalist, axis=0)

# %%
# all_test_data = data.copy()
# all_test_data.to_csv("/home/flexmatch_ftp/ftp/multimodal_categorizer/clip_fine_tuning/all_data_test.csv")
